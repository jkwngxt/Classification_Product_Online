# %% [markdown]
# # Import Library

# %%
import pandas as pd  # Import pandas for data manipulation and analysis
import numpy as np  # Import NumPy for numerical operations

from sklearn.preprocessing import LabelEncoder  # Import Label Encoder for converting categorical labels to numeric

from sklearn.model_selection import train_test_split  # Import train_test_split function
from sklearn.svm import SVC  # Importing the Support Vector Machine (SVM) classifier from scikit-learn
from sklearn.model_selection import GridSearchCV  # Importing the GridSearchCV module for hyperparameter tuning

from sklearn.metrics import accuracy_score # Import accuracy_score for accuracy calculation
import matplotlib.pyplot as plt  # Import matplotlib for data visualization
import seaborn as sns  # Import seaborn for statistical data visualization
from sklearn.metrics import confusion_matrix  # Import confusion_matrix for evaluating classification performance
from sklearn.metrics import classification_report  # Import classification_report for detailed classification metrics

# %% [markdown]
# # Load Data

# %%
# Load dataset
df = pd.read_csv("productOnline.csv")
df.sample(5)
# Out:
#        brand                                       product name class  \
# 175     Asus        Vivobook Pro 15 OLED M6500QC-LK541WS Laptop     C
# 54      Acer            TravelMate P2 TMP214-53 Business Laptop     B
# 807  Samsung                             Galaxy Book2 15 Laptop     C
# 389       HP                                14s-dq2649TU Laptop     A
# 526       HP  ZBook Firefly 16 G9 6V2X7PA Workstation PC Laptop     D
#
#                          processor                             CPU   Ram  \
# 175      5th Gen AMD Ryzen 5 5600H           Hexa Core, 12 Threads  16GB
# 54   11th Gen Intel Core i7 1165G7            Quad Core, 8 Threads  16GB
# 807   12th Gen Intel Core i7 1255U  10 Cores (2P + 8E), 12 Threads  16GB
# 389  11th Gen Intel Core i3 1115G4            Dual Core, 4 Threads   8GB
# 526   12th Gen Intel Core i7 1255U  10 Cores (2P + 8E), 12 Threads  16GB
#
#     Ram_type    ROM ROM_type                              GPU  display_size  \
# 175     DDR4  512GB      SSD  4GB NVIDIA GeForce RTX 3050 GPU          15.6
# 54      DDR4    1TB      SSD         Intel Integrated Iris Xe          14.0
# 807   LPDDR4  512GB      SSD           Intel Iris Xe Graphics          15.6
# 389     DDR4  512GB      SSD             Intel Integrated UHD          14.0
# 526     DDR5    1TB      SSD           Intel Iris Xe Graphics          16.0
#
#                 OS  warranty
# 175  Windows 11 OS         2
# 54   Windows 11 OS         1
# 807  Windows 11 OS         1
# 389  Windows 11 OS         1
# 526  Windows 11 OS         2

# %% [markdown]
# # Preprocessing

# %%
# Show dataframe information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 848 entries, 0 to 847
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         848 non-null    object
#  1   product name  848 non-null    object
#  2   class         848 non-null    object
#  3   processor     848 non-null    object
#  4   CPU           848 non-null    object
#  5   Ram           848 non-null    object
#  6   Ram_type      848 non-null    object
#  7   ROM           848 non-null    object
#  8   ROM_type      848 non-null    object
#  9   GPU           848 non-null    object
#  10  display_size  848 non-null    float64
#  11  OS            848 non-null    object
#  12  warranty      848 non-null    int64
# dtypes: float64(1), int64(1), object(11)
# memory usage: 86.2+ KB

# %%
# Assume feature and class name
feature_names = df.drop(labels=['class'], axis=1).columns.tolist()
class_names = df['class'].unique().tolist()

# Print the list of feature names
print("Feature Names:")
print(feature_names)

# Print the list of class names
print("\nClass Names:")
print(class_names)
# Out:
# Feature Names:
# ['brand', 'product name', 'processor', 'CPU', 'Ram', 'Ram_type', 'ROM', 'ROM_type', 'GPU', 'display_size', 'OS', 'warranty']
#
# Class Names:
# ['A', 'B', 'C', 'D']

# %%
# Lower cases data and count possible instances

# Function to lower cases data
def lower_cases_data(df) :
  for i in df.columns :
    if  df.loc[:,i].dtype == 'O':
      df.loc[:,i] = df.loc[:,i].str.lower()

# Function to count possible instances
def count_possible_instances(df) :
  for i in df.columns :
    print(i, ":", df.loc[:,i].value_counts())
    print("-------------------------------------")

# Call lower_cases_data function and count_possible_instances function
lower_cases_data(df)
count_possible_instances(df)
# Out:
# brand : brand
# hp           175
# lenovo       165
# asus         153
# dell          98
# acer          84
# msi           59
# samsung       26
# infinix       15
# apple          9
# xiaomi         8
# lg             8
# gigabyte       8
# fujitsu        6
# zebronics      4
# ultimus        4
# tecno          3
# wings          3
# realme         3
# chuwi          3
# honor          2
# axl            2
# microsoft      2
# huawei         2
# primebook      1
# razer          1
# ninkear        1
# vaio           1
# walker         1
# avita          1
# Name: count, dtype: int64
# -------------------------------------
# product name : product name
# inspiron 3525 laptop                 4
# inspiron 3511 laptop                 4
# megabook t1 laptop                   3
# vostro 3425 laptop                   3
# galaxy book2 15 laptop               3
#                                     ..
# inspiron 14 5430 2023 laptop         1
# inspiron 5425 laptop                 1
# inspiron 5518 d560667win9s laptop    1
# inspiron 5518 laptop                 1
# pro series z zeb-nbc 4s laptop       1
# Name: count, Length: 772, dtype: int64
# -------------------------------------
# class : class
# b    251
# c    225
# a    189
# d    183
# Name: count, dtype: int64
# -------------------------------------
# processor : processor
# 12th gen intel core i5 1235u     49
# 13th gen intel core i5 1335u     41
# 11th gen intel core i3 1115g4    40
# 12th gen intel core i3 1215u     38
# 12th gen intel core i5 12450h    33
#                                  ..
# 5th gen amd ryzen 3 5425u         1
# 5th gen amd ryzen 3  5425u        1
# 10th gen intel core i5 10210u     1
# 3rd gen amd ryzen 5  3500u        1
# 5th gen amd ryzen 7 5800h         1
# Name: count, Length: 162, dtype: int64
# -------------------------------------
# CPU : CPU
# quad core, 8 threads               130
# hexa core, 12 threads              126
# 10 cores (2p + 8e), 12 threads     121
# octa core, 16 threads              101
# 12 cores (4p + 8e), 16 threads      81
# dual core, 4 threads                55
# hexa core (2p + 4e), 8 threads      44
# octa core (4p + 4e), 12 threads     43
# dual core, 2 threads                36
# 14 cores (6p + 8e), 20 threads      36
# 10 cores (6p + 4e), 16 threads      25
# 16 cores (8p + 8e), 24 threads       9
# 14 cores (6p + 8e)                   9
# 5 cores (1p + 4e), 6 threads         7
# octa core (4p + 4e)                  5
# octa core, 8 threads                 4
# 24 cores (8p + 16e), 32 threads      4
# quad core, 4 threads                 4
# octa core                            2
# 10 cores, 12 threads                 2
# quad core                            1
# 14 cores, 20 threads                 1
# 20 threads                           1
# octa core, 12 threads                1
# Name: count, dtype: int64
# -------------------------------------
# Ram : Ram
# 16gb    441
# 8gb     368
# 4gb      22
# 32gb     15
# 12gb      2
# Name: count, dtype: int64
# -------------------------------------
# Ram_type : Ram_type
# ddr4       498
# ddr5       141
# lpddr5     133
# lpddr4x     54
# lpddr4      14
# lpddr5x      3
# ddr3         2
# unified      1
# ddr          1
# ddr4-        1
# Name: count, dtype: int64
# -------------------------------------
# ROM : ROM
# 512gb    631
# 1tb      155
# 256gb     41
# 128gb     12
# 64gb       5
# 2tb        3
# 32gb       1
# Name: count, dtype: int64
# -------------------------------------
# ROM_type : ROM_type
# ssd          828
# hard-disk     20
# Name: count, dtype: int64
# -------------------------------------
# GPU : GPU
# intel iris xe graphics             103
# intel uhd graphics                  63
# intel integrated uhd                61
# amd radeon amd                      55
# amd radeon graphics                 54
#                                   ...
# amd radeon 780m graphics             1
# intel integrated graphics            1
# intel uhd graphics 630               1
# 8gb nvidia geforce rtx 3070 ti       1
# intel graphics                       1
# Name: count, Length: 108, dtype: int64
# -------------------------------------
# display_size : display_size
# 15.60    461
# 14.00    212
# 16.00     93
# 13.30     28
# 16.10     19
# 17.30     11
# 11.60      6
# 14.10      6
# 15.00      3
# 13.60      2
# 15.30      2
# 13.40      2
# 13.50      1
# 15.56      1
# 17.00      1
# Name: count, dtype: int64
# -------------------------------------
# OS : OS
# windows 11 os         747
# windows 10 os          27
# dos os                 18
# windows 11  os         14
# chrome os              10
# windows 10  os         10
# windows os              8
# mac os                  6
# mac 10.15.3\t os        2
# ubuntu os               2
# dos 3.0 os              2
# mac high sierra os      1
# android 11 os           1
# Name: count, dtype: int64
# -------------------------------------
# warranty : warranty
# 1    512
# 2    252
# 3     84
# Name: count, dtype: int64
# -------------------------------------

# %%
# Normalize whitespace
for i in range(len(df.columns)) :
  column_temp = df.iloc[:,i]
  if  column_temp.dtype == 'O' :
    for j in range(len(column_temp)) :
      data_temp = df.iloc[j,i].split()
      df.iloc[j,i] = " ".join(data_temp)

# Call count_possible_instances function to checkup data
count_possible_instances(df)
# Out:
# brand : brand
# hp           175
# lenovo       165
# asus         153
# dell          98
# acer          84
# msi           59
# samsung       26
# infinix       15
# apple          9
# xiaomi         8
# lg             8
# gigabyte       8
# fujitsu        6
# zebronics      4
# ultimus        4
# tecno          3
# wings          3
# realme         3
# chuwi          3
# honor          2
# axl            2
# microsoft      2
# huawei         2
# primebook      1
# razer          1
# ninkear        1
# vaio           1
# walker         1
# avita          1
# Name: count, dtype: int64
# -------------------------------------
# product name : product name
# inspiron 3525 laptop                 4
# inspiron 3511 laptop                 4
# megabook t1 laptop                   3
# vostro 3425 laptop                   3
# galaxy book2 15 laptop               3
#                                     ..
# inspiron 14 5430 2023 laptop         1
# inspiron 5425 laptop                 1
# inspiron 5518 d560667win9s laptop    1
# inspiron 5518 laptop                 1
# pro series z zeb-nbc 4s laptop       1
# Name: count, Length: 772, dtype: int64
# -------------------------------------
# class : class
# b    251
# c    225
# a    189
# d    183
# Name: count, dtype: int64
# -------------------------------------
# processor : processor
# 12th gen intel core i5 1235u     51
# 11th gen intel core i3 1115g4    44
# 13th gen intel core i5 1335u     41
# 12th gen intel core i3 1215u     38
# 12th gen intel core i5 12450h    36
#                                  ..
# apple m2 apple m2 chip            1
# 12th gen intel core i5 1230u      1
# 8th gen intel core i5 8265u       1
# 7th gen amd ryzen 7 7840h         1
# 11th gen intel core i3 1125g4     1
# Name: count, Length: 115, dtype: int64
# -------------------------------------
# CPU : CPU
# quad core, 8 threads               130
# hexa core, 12 threads              126
# 10 cores (2p + 8e), 12 threads     121
# octa core, 16 threads              101
# 12 cores (4p + 8e), 16 threads      81
# dual core, 4 threads                55
# hexa core (2p + 4e), 8 threads      44
# octa core (4p + 4e), 12 threads     43
# dual core, 2 threads                36
# 14 cores (6p + 8e), 20 threads      36
# 10 cores (6p + 4e), 16 threads      25
# 16 cores (8p + 8e), 24 threads       9
# 14 cores (6p + 8e)                   9
# 5 cores (1p + 4e), 6 threads         7
# octa core (4p + 4e)                  5
# octa core, 8 threads                 4
# 24 cores (8p + 16e), 32 threads      4
# quad core, 4 threads                 4
# octa core                            2
# 10 cores, 12 threads                 2
# quad core                            1
# 14 cores, 20 threads                 1
# 20 threads                           1
# octa core, 12 threads                1
# Name: count, dtype: int64
# -------------------------------------
# Ram : Ram
# 16gb    441
# 8gb     368
# 4gb      22
# 32gb     15
# 12gb      2
# Name: count, dtype: int64
# -------------------------------------
# Ram_type : Ram_type
# ddr4       498
# ddr5       141
# lpddr5     133
# lpddr4x     54
# lpddr4      14
# lpddr5x      3
# ddr3         2
# unified      1
# ddr          1
# ddr4-        1
# Name: count, dtype: int64
# -------------------------------------
# ROM : ROM
# 512gb    631
# 1tb      155
# 256gb     41
# 128gb     12
# 64gb       5
# 2tb        3
# 32gb       1
# Name: count, dtype: int64
# -------------------------------------
# ROM_type : ROM_type
# ssd          828
# hard-disk     20
# Name: count, dtype: int64
# -------------------------------------
# GPU : GPU
# intel iris xe graphics         108
# intel uhd graphics              67
# intel integrated uhd            61
# amd radeon amd                  55
# amd radeon graphics             54
#                               ...
# amd radeon vega 8 graphics       1
# integrated uhd graphics 620      1
# 4gb nvidia rtx a500              1
# amd radeon 780m graphics         1
# amd radeon vega 8                1
# Name: count, Length: 96, dtype: int64
# -------------------------------------
# display_size : display_size
# 15.60    461
# 14.00    212
# 16.00     93
# 13.30     28
# 16.10     19
# 17.30     11
# 11.60      6
# 14.10      6
# 15.00      3
# 13.60      2
# 15.30      2
# 13.40      2
# 13.50      1
# 15.56      1
# 17.00      1
# Name: count, dtype: int64
# -------------------------------------
# OS : OS
# windows 11 os         761
# windows 10 os          37
# dos os                 18
# chrome os              10
# windows os              8
# mac os                  6
# mac 10.15.3 os          2
# ubuntu os               2
# dos 3.0 os              2
# mac high sierra os      1
# android 11 os           1
# Name: count, dtype: int64
# -------------------------------------
# warranty : warranty
# 1    512
# 2    252
# 3     84
# Name: count, dtype: int64
# -------------------------------------

# %%
# Encode string data (Features)
for i in df.drop(labels='class', axis=1).columns:
    if df[i].dtype == 'O':
        label_encoder = LabelEncoder()
        df[i] = label_encoder.fit_transform(df[i])

# Encode string data (Target)
dic = {'a': 0, 'b': 1, 'c' : 2, 'd' : 3}
df['class'] = df['class'].map(dic)

# Call count_possible_instances function to checkup data
count_possible_instances(df)
# Out:
# brand : brand
# 10    175
# 13    165
# 2     153
# 6      98
# 0      84
# 16     59
# 21     26
# 12     15
# 1       9
# 27      8
# 14      8
# 8       8
# 7       6
# 28      4
# 23      4
# 22      3
# 26      3
# 20      3
# 5       3
# 9       2
# 4       2
# 15      2
# 11      2
# 18      1
# 19      1
# 17      1
# 24      1
# 25      1
# 3       1
# Name: count, dtype: int64
# -------------------------------------
# product name : product name
# 299    4
# 290    4
# 374    3
# 733    3
# 184    3
#       ..
# 283    1
# 312    1
# 319    1
# 320    1
# 468    1
# Name: count, Length: 772, dtype: int64
# -------------------------------------
# class : class
# 1    251
# 2    225
# 0    189
# 3    183
# Name: count, dtype: int64
# -------------------------------------
# processor : processor
# 27     51
# 12     44
# 42     41
# 24     38
# 29     36
#        ..
# 105     1
# 26      1
# 94      1
# 89      1
# 13      1
# Name: count, Length: 115, dtype: int64
# -------------------------------------
# CPU : CPU
# 23    130
# 14    126
# 0     121
# 19    101
# 3      81
# 12     55
# 13     44
# 17     43
# 11     36
# 5      36
# 1      25
# 7       9
# 4       9
# 10      7
# 16      5
# 20      4
# 9       4
# 22      4
# 15      2
# 2       2
# 21      1
# 6       1
# 8       1
# 18      1
# Name: count, dtype: int64
# -------------------------------------
# Ram : Ram
# 1    441
# 4    368
# 3     22
# 2     15
# 0      2
# Name: count, dtype: int64
# -------------------------------------
# Ram_type : Ram_type
# 2    498
# 4    141
# 7    133
# 6     54
# 5     14
# 8      3
# 1      2
# 9      1
# 0      1
# 3      1
# Name: count, dtype: int64
# -------------------------------------
# ROM : ROM
# 5    631
# 1    155
# 2     41
# 0     12
# 6      5
# 3      3
# 4      1
# Name: count, dtype: int64
# -------------------------------------
# ROM_type : ROM_type
# 1    828
# 0     20
# Name: count, dtype: int64
# -------------------------------------
# GPU : GPU
# 88    108
# 90     67
# 79     61
# 50     55
# 51     54
#      ...
# 59      1
# 67      1
# 31      1
# 49      1
# 58      1
# Name: count, Length: 96, dtype: int64
# -------------------------------------
# display_size : display_size
# 15.60    461
# 14.00    212
# 16.00     93
# 13.30     28
# 16.10     19
# 17.30     11
# 11.60      6
# 14.10      6
# 15.00      3
# 13.60      2
# 15.30      2
# 13.40      2
# 13.50      1
# 15.56      1
# 17.00      1
# Name: count, dtype: int64
# -------------------------------------
# OS : OS
# 9     761
# 8      37
# 3      18
# 1      10
# 10      8
# 6       6
# 4       2
# 7       2
# 2       2
# 5       1
# 0       1
# Name: count, dtype: int64
# -------------------------------------
# warranty : warranty
# 1    512
# 2    252
# 3     84
# Name: count, dtype: int64
# -------------------------------------

# %%
# Define X and y : X is feature. y is answer lable of X.
X = df.drop(labels = "class",  axis=1)
X
# Out:
#      brand  product name  processor  CPU  Ram  Ram_type  ROM  ROM_type  GPU  \
# 0        0           120        107   11    3         6    6         0   79
# 1        0           416        109   11    4         2    0         1   79
# 2        0           415        109   11    4         2    2         1   79
# 3        0           419         59   12    4         2    2         1   51
# 4        0           422         12   12    4         2    2         1   88
# ..     ...           ...        ...  ...  ...       ...  ...       ...  ...
# 843     27           375         15   23    1         6    5         1   88
# 844     28           760         24   13    4         2    5         1   70
# 845     28           759         19   23    1         6    5         1   79
# 846     28           467         27    0    4         2    5         1   70
# 847     28           468         27    0    1         2    5         1   70
#
#      display_size  OS  warranty
# 0            11.6   1         1
# 1            11.6   9         1
# 2            11.6   9         2
# 3            14.0   9         2
# 4            14.0   9         1
# ..            ...  ..       ...
# 843          15.6   8         3
# 844          15.6   9         1
# 845          15.6   9         1
# 846          15.6   9         1
# 847          15.6   9         2
#
# [848 rows x 12 columns]

# %%
y = df['class']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 843    2
# 844    0
# 845    0
# 846    0
# 847    1
# Name: class, Length: 848, dtype: int64

# %% [markdown]
# # Train Test Split

# %%
# Dividing the dataset into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15  , random_state=189) # 85% training and 15% test

# %% [markdown]
# # Find the Best Hyperparameters

# %% [markdown]
# Using grid search to find the best hyperparameters for the support vector machine (SVM) classifier

# %%
# Define a dictionary 'grid' where each key represents a hyperparameter's name,
# and the corresponding value is a list of values to compare during the grid search
grid = {
    'decision_function_shape': ['ovo'],
    'kernel': ['rbf'],
    'gamma': [0.1, 0.001, 0.0001],
    'C': [0.1, 1, 10, 50, 100, 1000],
    'tol': [0.1, 0.01, 0.001],
    'shrinking': [True, False]
}

# Creating an instance of the Support Vector Machine (SVM) classifier
svm = SVC()

# Creating an instance of GridSearchCV with the SVM classifier and hyperparameter grid
svm_cv = GridSearchCV(svm, grid, cv = 2)  # 2-fold Cross-Validation

# Fitting the GridSearchCV instance to the training data
svm_cv.fit(X_train, y_train)

# Print the best parameters found by GridSearchCV
print("Best Parameters:",svm_cv.best_params_)
# Out:
# Best Parameters: {'C': 1000, 'decision_function_shape': 'ovo', 'gamma': 0.0001, 'kernel': 'rbf', 'shrinking': True, 'tol': 0.1}

# %%
# Get the best SVM model with the optimal hyperparameters
best_svm = svm_cv.best_estimator_

# Train the SVM with the best hyperparameters on the entire training set
best_svm.fit(X_train, y_train)

# Predict on the test set
y_pred = best_svm.predict(X_test)

# Evaluate the performance on the test set
accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy:", accuracy)
# Out:
# Test Accuracy: 0.8203125

# %%
# Show confusion matrix

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Create a subplot
ax = plt.subplot()

# Display the confusion matrix as a heatmap with annotations
sns.heatmap(cm, annot=True, ax=ax, cmap="coolwarm")

# Set the title and axis labels
ax.set_title("Confusion Matrix")
ax.set_xlabel("Predicted labels")
ax.set_ylabel("Actual labels")

# Set tick labels for both axes using class names
ax.xaxis.set_ticklabels(class_names)
ax.yaxis.set_ticklabels(class_names)

# Show the plot
plt.show()

# %%
# Generate and print the classification report
report = classification_report(y_test, y_pred, target_names=class_names, digits=4)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            A     0.8000    0.9655    0.8750        29
#            B     0.8857    0.7949    0.8378        39
#            C     0.7000    0.7778    0.7368        27
#            D     0.8929    0.7576    0.8197        33
#
#     accuracy                         0.8203       128
#    macro avg     0.8196    0.8239    0.8173       128
# weighted avg     0.8290    0.8203    0.8203       128
